# %%
import os
import gc
import math
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
SAVE_PATH = "/kaggle/working/checkpoints/"

os.makedirs(SAVE_PATH, exist_ok=True)

# %%
import os

for root, dirs, files in os.walk("/kaggle/input"):
    for f in files:
        if "LOOPSEA_10" in f:
            print(os.path.join(root, f))

# %%
import os

for root, dirs, files in os.walk("/kaggle/working"):
    for f in files:
        print(os.path.join(root, f))
# Out:
# /kaggle/working/__notebook__.ipynb

# %%
files = {
     0: "/kaggle/input/datasets/chetanrnarware/pims-bay/missing_data/pemsbay_0percent_missing.csv",
    10: "/kaggle/input/datasets/chetanrnarware/pims-bay/missing_data/pemsbay_10percent_missing.csv",
    20: "/kaggle/input/datasets/chetanrnarware/pims-bay/missing_data/pemsbay_20percent_missing.csv",
    40: "/kaggle/input/datasets/chetanrnarware/pims-bay/missing_data/pemsbay_40percent_missing.csv",
    80: "/kaggle/input/datasets/chetanrnarware/pims-bay/missing_data/pemsbay_80percent_missing.csv",
}
print("Files configured:", list(files.keys()))
# Out:
# Files configured: [0, 10, 20, 40, 80]

# %%
import os
print(os.path.exists(files[10]))
# Out:
# True

# %%
def create_sequences(data, mask, seq_len=10):
    X, M, Y = [], [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        M.append(mask[i:i+seq_len])
        Y.append(data[i+seq_len])
    return np.array(X), np.array(M), np.array(Y)

# %%
class TrafficDataset(Dataset):
    def __init__(self, X, M, Y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.M = torch.tensor(M, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.M[idx], self.Y[idx]

# %%
class ConvLSTMCell(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.conv = nn.Conv1d(
            input_dim + hidden_dim,
            4 * hidden_dim,
            kernel_size=3,
            padding=1
        )
        self.dropout = nn.Dropout(0.1)

    def forward(self, x, h, c):
        combined = torch.cat([x, h], dim=1)          # (B, input+hidden, F)
        i, f, o, g = torch.chunk(self.conv(combined), 4, dim=1)
        i = torch.sigmoid(i)
        f = torch.sigmoid(f)
        o = torch.sigmoid(o)
        g = torch.tanh(g)
        c = f * c + i * g
        h = o * torch.tanh(c)
        h = self.dropout(h)
        return h, c

# %%
class IConvLSTM(nn.Module):
    """
    ConvLSTM with imputation unit following Cui et al. (2020).

    Key fixes vs previous version:
      - Imputation uses BOTH h and c (cell state), matching Eq.10 of paper
      - Returns only the LAST timestep output (not mean over all T)
      - No broken residual addition across mismatched channel dims
      - Mask is fed into all gates (matching LSTM-I Eqs. 13-16)
    """
    def __init__(self, input_dim, hidden_dim=64):
        super().__init__()
        self.hidden_dim = hidden_dim

        # Imputation unit: infers x̃_t from preceding h and c (Eq. 10)
        # Concat h2 + c2 along channel dim → 2*hidden_dim channels
        self.impute = nn.Sequential(
            nn.Conv1d(2 * hidden_dim, hidden_dim, kernel_size=1),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, 1, kernel_size=1),
            nn.Sigmoid()   # speeds constrained 0-1 after normalization
        )

        # Layer 1: input is 1 (single-channel speed) + 1 (mask channel)
        # We concatenate mask as an extra input channel (matching Eqs. 13-16)
        self.convlstm1 = ConvLSTMCell(input_dim=2, hidden_dim=hidden_dim)

        # Layer 2: input is hidden_dim from layer 1
        self.convlstm2 = ConvLSTMCell(input_dim=hidden_dim, hidden_dim=hidden_dim)

        # Final 1x1 conv to map hidden → prediction
        self.output_head = nn.Conv1d(hidden_dim, 1, kernel_size=1)

    def forward(self, x, mask):
        """
        x    : (B, T, F)   normalized speed sequences
        mask : (B, T, F)   1=observed, 0=missing
        Returns:
          pred        : (B, F)   prediction for timestep T+1
          imputations : (B, T, F) inferred values at each step
        """
        B, T, F = x.shape

        # Initialize states
        h1 = torch.zeros(B, self.hidden_dim, F, device=x.device)
        c1 = torch.zeros(B, self.hidden_dim, F, device=x.device)
        h2 = torch.zeros(B, self.hidden_dim, F, device=x.device)
        c2 = torch.zeros(B, self.hidden_dim, F, device=x.device)

        imputations = []

        for t in range(T):
            xt = x[:, t, :].unsqueeze(1)       # (B, 1, F)
            mt = mask[:, t, :].unsqueeze(1)     # (B, 1, F)

            # --- Imputation unit (Eq. 10) ---
            # Infer missing values from previous layer-2 h AND c
            x_tilde = self.impute(torch.cat([h2, c2], dim=1))   # (B, 1, F)

            # --- Mask fusion (Eq. 11-12) ---
            # Use observed value where available, imputed value where missing
            x_prime = mt * xt + (1.0 - mt) * x_tilde            # (B, 1, F)

            imputations.append(x_tilde.squeeze(1))               # (B, F)

            # --- Layer 1: feed x_prime + mask as 2-channel input ---
            x_with_mask = torch.cat([x_prime, mt], dim=1)        # (B, 2, F)
            h1, c1 = self.convlstm1(x_with_mask, h1, c1)

            # --- Layer 2 ---
            h2, c2 = self.convlstm2(h1, h2, c2)

        # Predict only from LAST hidden state (matches paper Eq. 2)
        pred = self.output_head(h2).squeeze(1)                   # (B, F)
        imputations = torch.stack(imputations, dim=1)            # (B, T, F)

        return pred, imputations

# %%
def compute_loss(pred, target, imputations, x_input, mask, lam=0.1):
    """
    Combined prediction + imputation regularization loss.
      L = Loss(pred, target) + λ * Σ |x_t - x̃_t| over OBSERVED positions

    Critical: imputation error is measured on OBSERVED values (mask==1)
    because those are the only positions where we have ground truth.
    """
    # Prediction loss: MAE + small MSE term for sharper gradients
    pred_loss = torch.mean(torch.abs(pred - target)) + \
                0.1 * torch.mean((pred - target) ** 2)

    # Imputation regularization on observed positions only
    # mask shape: (B, T, F), imputations shape: (B, T, F), x_input shape: (B, T, F)
    imp_error = torch.abs(imputations - x_input) * mask   # zero out missing positions
    imp_loss  = imp_error.sum() / (mask.sum() + 1e-8)

    return pred_loss + lam * imp_loss

# %%
def hybrid_loss(pred, target):
    mse = torch.mean((pred - target) ** 2)
    mae = torch.mean(torch.abs(pred - target))
    return 0.5 * mse + mae

# %%
def train_model(model, train_loader, val_loader, percent,
                max_epochs=80, patience=15):
    optimizer = torch.optim.Adam(
        model.parameters(), lr=1e-3, weight_decay=1e-5
    )
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=8, min_lr=1e-5
    )

    best_loss = float("inf")
    wait = 0
    best_path = f"/kaggle/working/best_{percent}.pt"

    for epoch in range(max_epochs):
        # ---- Train ----
        model.train()
        train_loss = 0.0
        for x, m, y in train_loader:
            x, m, y = x.to(device), m.to(device), y.to(device)
            optimizer.zero_grad()
            pred, imputations = model(x, m)
            loss = compute_loss(pred, y, imputations, x, m, lam=0.1)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader)

        # ---- Validate ----
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x, m, y in val_loader:
                x, m, y = x.to(device), m.to(device), y.to(device)
                pred, _ = model(x, m)
                val_loss += (torch.mean(torch.abs(pred - y)) +
                             0.1 * torch.mean((pred - y) ** 2)).item()
        val_loss /= len(val_loader)

        current_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']
        lr_msg = f"  → LR dropped to {new_lr:.2e}" if new_lr < current_lr else ""

        print(f"Epoch {epoch+1:3d}  Train {train_loss:.4f}  Val {val_loss:.4f}  "
              f"LR {current_lr:.2e}{lr_msg}")

        if val_loss < best_loss:
            best_loss = val_loss
            wait = 0
            # Save underlying model weights (unwrap DataParallel if needed)
            state = model.module.state_dict() if isinstance(model, nn.DataParallel) \
                    else model.state_dict()
            torch.save(state, best_path)
            print("  ✓ Saved best model")
        else:
            wait += 1
            if wait >= patience:
                print(f"  Early stopping at epoch {epoch+1}")
                break

    # Load best weights back (unwrap-safe)
    state = torch.load(best_path)
    if isinstance(model, nn.DataParallel):
        model.module.load_state_dict(state)
    else:
        model.load_state_dict(state)

    return model

# %%
def evaluate_model(model, loader, mean, std):
    model.eval()
    preds, trues, masks = [], [], []

    with torch.no_grad():
        for x, m, y in loader:
            x, m = x.to(device), m.to(device)
            pred, _ = model(x, m)
            preds.append(pred.cpu().numpy())
            trues.append(y.numpy())
            masks.append(m[:, -1, :].cpu().numpy())

    preds = np.concatenate(preds)   # (N, F)
    trues = np.concatenate(trues)   # (N, F)
    masks = np.concatenate(masks)   # (N, F)

    # --- Normalized metrics ---
    mae_norm  = mean_absolute_error(trues.ravel(), preds.ravel())
    rmse_norm = np.sqrt(mean_squared_error(trues.ravel(), preds.ravel()))

    # --- Denormalize: mean/std shape (1, F) → broadcasts correctly ---
    preds_real = preds * std + mean   # (N, F)
    trues_real = trues * std + mean   # (N, F)

    mae_real  = mean_absolute_error(trues_real.ravel(), preds_real.ravel())
    rmse_real = np.sqrt(mean_squared_error(trues_real.ravel(), preds_real.ravel()))

    # Per-sensor R2, then average
    r2_list = [r2_score(trues_real[:, i], preds_real[:, i])
               for i in range(trues_real.shape[1])]
    r2_real = np.mean(r2_list)

    # MAPE on observed, non-zero ground truth
    valid = (np.abs(trues_real) > 1e-3) & (masks == 1)
    mape  = np.mean(np.abs((trues_real[valid] - preds_real[valid]) /
                            trues_real[valid])) * 100

    print("\n==============================")
    print("Normalized Results")
    print("==============================")
    print(f"MAE  : {mae_norm:.4f}")
    print(f"RMSE : {rmse_norm:.4f}")
    print("\n==============================")
    print("Denormalized Results (Real Scale)")
    print("==============================")
    print(f"MAE  : {mae_real:.4f}")
    print(f"RMSE : {rmse_real:.4f}")
    print(f"R2   : {r2_real:.4f}")
    print(f"MAPE : {mape:.2f}%")

    return mae_real, rmse_real, r2_real, mape

# %%
def train_single_dataset(percent, model_name="pemabay_iconv"):
    print(f"\nRunning {percent}% missing experiment")

    raw = pd.read_csv(files[percent])
    raw = raw.apply(pd.to_numeric, errors='coerce')

    mask = (~raw.isna()).astype(np.float32).values
    data = raw.values.astype(np.float32)

    # Warm-start: mark first 200 rows as observed and fill NaNs with column median
    mask[:200, :] = 1.0
    col_medians = np.nanmedian(data, axis=0)
    col_medians = np.where(np.isnan(col_medians), 0.0, col_medians)
    for col in range(data.shape[1]):
        nan_rows = np.isnan(data[:200, col])
        if nan_rows.any():
            data[:200, col][nan_rows] = col_medians[col]

    # Train/val split
    split = int(0.8 * len(data))
    train_data, val_data = data[:split],  data[split:]
    train_mask, val_mask = mask[:split],  mask[split:]

    # Compute mean/std ONLY on observed training values
    obs_train = train_data.copy()
    obs_train[train_mask == 0] = np.nan
    mean = np.nanmean(obs_train, axis=0, keepdims=True)
    std  = np.nanstd(obs_train,  axis=0, keepdims=True)

    # Handle sensors entirely missing in training set
    mean = np.where(np.isnan(mean), 0.0, mean)
    std  = np.where(np.isnan(std) | (std < 1e-8), 1.0, std)

    # Normalize: observed → (x-mean)/std, missing → 0
    train_norm = np.where(train_mask == 1, (train_data - mean) / std, 0.0)
    val_norm   = np.where(val_mask   == 1, (val_data   - mean) / std, 0.0)

    SEQ_LEN = 10
    X_tr, M_tr, Y_tr = create_sequences(train_norm, train_mask, SEQ_LEN)
    X_vl, M_vl, Y_vl = create_sequences(val_norm,   val_mask,   SEQ_LEN)

    # num_workers=4 to keep both GPUs fed
    train_loader = DataLoader(
        TensorDataset(
            torch.tensor(X_tr, dtype=torch.float32),
            torch.tensor(M_tr, dtype=torch.float32),
            torch.tensor(Y_tr, dtype=torch.float32)
        ),
        batch_size=64, shuffle=True,  num_workers=4, pin_memory=True
    )
    val_loader = DataLoader(
        TensorDataset(
            torch.tensor(X_vl, dtype=torch.float32),
            torch.tensor(M_vl, dtype=torch.float32),
            torch.tensor(Y_vl, dtype=torch.float32)
        ),
        batch_size=64, shuffle=False, num_workers=4, pin_memory=True
    )

    input_dim = X_tr.shape[2]
    model = IConvLSTM(input_dim=input_dim, hidden_dim=64).to(device)

    # --- DataParallel: use both T4s if available ---
    if torch.cuda.device_count() > 1:
        print(f"Using {torch.cuda.device_count()} GPUs")
        model = nn.DataParallel(model)

    print(f"Parameters: {sum(p.numel() for p in model.parameters()):,}")

    model = train_model(model, train_loader, val_loader, percent)

    # Unwrap DataParallel before saving so .pt files load cleanly later
    state = model.module.state_dict() if isinstance(model, nn.DataParallel) \
            else model.state_dict()

    save_path = f"/kaggle/working/{model_name}_{percent}.pt"
    torch.save({"model": state, "mean": mean, "std": std}, save_path)
    print("Saved:", save_path)

    mae, rmse, r2, mape = evaluate_model(model, val_loader, mean, std)
    return mae, rmse, r2, mape

# %%
def clear_memory():
    gc.collect()
    torch.cuda.empty_cache()

# %%
results = {}

# %%
import gc

def clear_memory():
    gc.collect()
    torch.cuda.empty_cache()

results = {}

for pct in [10, 40]:
    print(f"\n{'='*10} {pct}% Missing {'='*10}")
    results[pct] = train_single_dataset(pct)
    mae, rmse, r2, mape = results[pct]
    print(f"\nFINAL RESULT {pct}%")
    print(f"MAE  : {mae:.4f}")
    print(f"RMSE : {rmse:.4f}")
    print(f"R2   : {r2:.4f}")
    print(f"MAPE : {mape:.2f}%")
    clear_memory()

print("\n==============================")
print("PARTIAL SUMMARY (10% and 40%)")
print("==============================")
for k in [10, 40]:
    mae, rmse, r2, mape = results[k]
    print(f"{k:3d}% -> MAE: {mae:.4f}, RMSE: {rmse:.4f}, R2: {r2:.4f}, MAPE: {mape:.2f}%")
# Out:
# ========== 10% Missing ==========
#
# Running 10% missing experiment
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1233: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
# Using 2 GPUs
# Parameters: 157,890
# Epoch   1  Train 0.2763  Val 0.2045  LR 1.00e-03
#   ✓ Saved best model
# Epoch   2  Train 0.2376  Val 0.1985  LR 1.00e-03
#   ✓ Saved best model
# Epoch   3  Train 0.2341  Val 0.1954  LR 1.00e-03
#   ✓ Saved best model
# Epoch   4  Train 0.2327  Val 0.1947  LR 1.00e-03
#   ✓ Saved best model
# Epoch   5  Train 0.2319  Val 0.1948  LR 1.00e-03
# Epoch   6  Train 0.2314  Val 0.1935  LR 1.00e-03
#   ✓ Saved best model
# Epoch   7  Train 0.2309  Val 0.1941  LR 1.00e-03
# Epoch   8  Train 0.2305  Val 0.1934  LR 1.00e-03
#   ✓ Saved best model
# Epoch   9  Train 0.2301  Val 0.1937  LR 1.00e-03
# Epoch  10  Train 0.2298  Val 0.1934  LR 1.00e-03
#   ✓ Saved best model
# Epoch  11  Train 0.2296  Val 0.1919  LR 1.00e-03
#   ✓ Saved best model
# Epoch  12  Train 0.2293  Val 0.1918  LR 1.00e-03
#   ✓ Saved best model
# Epoch  13  Train 0.2293  Val 0.1923  LR 1.00e-03
# Epoch  14  Train 0.2289  Val 0.1924  LR 1.00e-03
# Epoch  15  Train 0.2289  Val 0.1920  LR 1.00e-03
# Epoch  16  Train 0.2289  Val 0.1918  LR 1.00e-03
#   ✓ Saved best model
# Epoch  17  Train 0.2286  Val 0.1920  LR 1.00e-03
# Epoch  18  Train 0.2286  Val 0.1917  LR 1.00e-03
#   ✓ Saved best model
# Epoch  19  Train 0.2285  Val 0.1922  LR 1.00e-03
# Epoch  20  Train 0.2283  Val 0.1918  LR 1.00e-03
# Epoch  21  Train 0.2283  Val 0.1923  LR 1.00e-03
# Epoch  22  Train 0.2282  Val 0.1910  LR 1.00e-03
#   ✓ Saved best model
# Epoch  23  Train 0.2282  Val 0.1913  LR 1.00e-03
# Epoch  24  Train 0.2281  Val 0.1914  LR 1.00e-03
# Epoch  25  Train 0.2280  Val 0.1909  LR 1.00e-03
#   ✓ Saved best model
# Epoch  26  Train 0.2280  Val 0.1906  LR 1.00e-03
#   ✓ Saved best model
# Epoch  27  Train 0.2280  Val 0.1910  LR 1.00e-03
# Epoch  28  Train 0.2278  Val 0.1907  LR 1.00e-03
# Epoch  29  Train 0.2278  Val 0.1912  LR 1.00e-03
# Epoch  30  Train 0.2279  Val 0.1905  LR 1.00e-03
#   ✓ Saved best model
# Epoch  31  Train 0.2278  Val 0.1904  LR 1.00e-03
#   ✓ Saved best model
# Epoch  32  Train 0.2277  Val 0.1912  LR 1.00e-03
# Epoch  33  Train 0.2278  Val 0.1908  LR 1.00e-03
# Epoch  34  Train 0.2277  Val 0.1905  LR 1.00e-03
# Epoch  35  Train 0.2278  Val 0.1908  LR 1.00e-03
# Epoch  36  Train 0.2276  Val 0.1913  LR 1.00e-03
# Epoch  37  Train 0.2276  Val 0.1903  LR 1.00e-03
#   ✓ Saved best model
# Epoch  38  Train 0.2276  Val 0.1906  LR 1.00e-03
# Epoch  39  Train 0.2275  Val 0.1908  LR 1.00e-03
# Epoch  40  Train 0.2275  Val 0.1916  LR 1.00e-03
# Epoch  41  Train 0.2276  Val 0.1904  LR 1.00e-03
# Epoch  42  Train 0.2275  Val 0.1900  LR 1.00e-03
#   ✓ Saved best model
# Epoch  43  Train 0.2276  Val 0.1901  LR 1.00e-03
# Epoch  44  Train 0.2273  Val 0.1906  LR 1.00e-03
# Epoch  45  Train 0.2275  Val 0.1903  LR 1.00e-03
# Epoch  46  Train 0.2275  Val 0.1909  LR 1.00e-03
# Epoch  47  Train 0.2274  Val 0.1901  LR 1.00e-03
# Epoch  48  Train 0.2274  Val 0.1906  LR 1.00e-03
# Epoch  49  Train 0.2273  Val 0.1909  LR 1.00e-03
# Epoch  50  Train 0.2274  Val 0.1902  LR 1.00e-03
# Epoch  51  Train 0.2274  Val 0.1904  LR 1.00e-03  → LR dropped to 5.00e-04
# Epoch  52  Train 0.2269  Val 0.1904  LR 5.00e-04
# Epoch  53  Train 0.2269  Val 0.1898  LR 5.00e-04
#   ✓ Saved best model
# Epoch  54  Train 0.2270  Val 0.1900  LR 5.00e-04
# Epoch  55  Train 0.2270  Val 0.1899  LR 5.00e-04
# Epoch  56  Train 0.2269  Val 0.1900  LR 5.00e-04
# Epoch  57  Train 0.2269  Val 0.1898  LR 5.00e-04
# Epoch  58  Train 0.2270  Val 0.1905  LR 5.00e-04
# Epoch  59  Train 0.2269  Val 0.1902  LR 5.00e-04
# Epoch  60  Train 0.2269  Val 0.1902  LR 5.00e-04
# Epoch  61  Train 0.2269  Val 0.1901  LR 5.00e-04
# Epoch  62  Train 0.2268  Val 0.1909  LR 5.00e-04  → LR dropped to 2.50e-04
# Epoch  63  Train 0.2266  Val 0.1899  LR 2.50e-04
# Epoch  64  Train 0.2266  Val 0.1897  LR 2.50e-04
#   ✓ Saved best model
# Epoch  65  Train 0.2266  Val 0.1895  LR 2.50e-04
#   ✓ Saved best model
# Epoch  66  Train 0.2266  Val 0.1899  LR 2.50e-04
# Epoch  67  Train 0.2266  Val 0.1895  LR 2.50e-04
#   ✓ Saved best model
# Epoch  68  Train 0.2267  Val 0.1897  LR 2.50e-04
# Epoch  69  Train 0.2267  Val 0.1900  LR 2.50e-04
# Epoch  70  Train 0.2266  Val 0.1899  LR 2.50e-04
# Epoch  71  Train 0.2266  Val 0.1897  LR 2.50e-04
# Epoch  72  Train 0.2266  Val 0.1896  LR 2.50e-04
# Epoch  73  Train 0.2266  Val 0.1899  LR 2.50e-04
# Epoch  74  Train 0.2267  Val 0.1897  LR 2.50e-04
# Epoch  75  Train 0.2266  Val 0.1897  LR 2.50e-04
# Epoch  76  Train 0.2266  Val 0.1899  LR 2.50e-04  → LR dropped to 1.25e-04
# Epoch  77  Train 0.2265  Val 0.1897  LR 1.25e-04
# Epoch  78  Train 0.2264  Val 0.1897  LR 1.25e-04
# Epoch  79  Train 0.2264  Val 0.1896  LR 1.25e-04
# Epoch  80  Train 0.2265  Val 0.1895  LR 1.25e-04
# Saved: /kaggle/working/pemabay_iconv_10.pt
# ==============================
# Normalized Results
# ==============================
# MAE  : 0.1739
# RMSE : 0.3956
#
# ==============================
# Denormalized Results (Real Scale)
# ==============================
# MAE  : 1.3622
# RMSE : 3.3387
# R2   : 0.8281
# MAPE : 2.43%
#
# FINAL RESULT 10%
# MAE  : 1.3622
# RMSE : 3.3387
# R2   : 0.8281
# MAPE : 2.43%
# ========== 40% Missing ==========
#
# Running 40% missing experiment
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1233: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
# Using 2 GPUs
# Parameters: 157,890
# Epoch   1  Train 0.3972  Val 0.3544  LR 1.00e-03
#   ✓ Saved best model
# Epoch   2  Train 0.3839  Val 0.3510  LR 1.00e-03
#   ✓ Saved best model
# Epoch   3  Train 0.3819  Val 0.3499  LR 1.00e-03
#   ✓ Saved best model
# Epoch   4  Train 0.3811  Val 0.3494  LR 1.00e-03
#   ✓ Saved best model
# Epoch   5  Train 0.3805  Val 0.3490  LR 1.00e-03
#   ✓ Saved best model
# Epoch   6  Train 0.3800  Val 0.3485  LR 1.00e-03
#   ✓ Saved best model
# Epoch   7  Train 0.3797  Val 0.3485  LR 1.00e-03
#   ✓ Saved best model
# Epoch   8  Train 0.3793  Val 0.3478  LR 1.00e-03
#   ✓ Saved best model
# Epoch   9  Train 0.3789  Val 0.3480  LR 1.00e-03
# Epoch  10  Train 0.3789  Val 0.3475  LR 1.00e-03
#   ✓ Saved best model
# Epoch  11  Train 0.3786  Val 0.3475  LR 1.00e-03
# Epoch  12  Train 0.3787  Val 0.3475  LR 1.00e-03
# Epoch  13  Train 0.3784  Val 0.3475  LR 1.00e-03
# Epoch  14  Train 0.3785  Val 0.3472  LR 1.00e-03
#   ✓ Saved best model
# Epoch  15  Train 0.3782  Val 0.3476  LR 1.00e-03
# Epoch  16  Train 0.3782  Val 0.3472  LR 1.00e-03
#   ✓ Saved best model
# Epoch  17  Train 0.3781  Val 0.3472  LR 1.00e-03
# Epoch  18  Train 0.3782  Val 0.3470  LR 1.00e-03
#   ✓ Saved best model
# Epoch  19  Train 0.3780  Val 0.3471  LR 1.00e-03
# Epoch  20  Train 0.3780  Val 0.3473  LR 1.00e-03
# Epoch  21  Train 0.3780  Val 0.3469  LR 1.00e-03
#   ✓ Saved best model
# Epoch  22  Train 0.3779  Val 0.3471  LR 1.00e-03
# Epoch  23  Train 0.3779  Val 0.3468  LR 1.00e-03
#   ✓ Saved best model
# Epoch  24  Train 0.3778  Val 0.3465  LR 1.00e-03
#   ✓ Saved best model
# Epoch  25  Train 0.3777  Val 0.3470  LR 1.00e-03
# Epoch  26  Train 0.3777  Val 0.3468  LR 1.00e-03
# Epoch  27  Train 0.3777  Val 0.3470  LR 1.00e-03
# Epoch  28  Train 0.3776  Val 0.3470  LR 1.00e-03
# Epoch  29  Train 0.3775  Val 0.3468  LR 1.00e-03
# Epoch  30  Train 0.3776  Val 0.3465  LR 1.00e-03
# Epoch  31  Train 0.3776  Val 0.3468  LR 1.00e-03
# Epoch  32  Train 0.3776  Val 0.3465  LR 1.00e-03
# Epoch  33  Train 0.3777  Val 0.3465  LR 1.00e-03  → LR dropped to 5.00e-04
#   ✓ Saved best model
# Epoch  34  Train 0.3772  Val 0.3465  LR 5.00e-04
#   ✓ Saved best model
# Epoch  35  Train 0.3770  Val 0.3465  LR 5.00e-04
# Epoch  36  Train 0.3771  Val 0.3464  LR 5.00e-04
#   ✓ Saved best model
# Epoch  37  Train 0.3771  Val 0.3464  LR 5.00e-04
# Epoch  38  Train 0.3771  Val 0.3463  LR 5.00e-04
#   ✓ Saved best model
# Epoch  39  Train 0.3770  Val 0.3462  LR 5.00e-04
#   ✓ Saved best model
# Epoch  40  Train 0.3770  Val 0.3462  LR 5.00e-04
#   ✓ Saved best model
# Epoch  41  Train 0.3771  Val 0.3462  LR 5.00e-04
#   ✓ Saved best model
# Epoch  42  Train 0.3771  Val 0.3463  LR 5.00e-04
# Epoch  43  Train 0.3770  Val 0.3463  LR 5.00e-04
# Epoch  44  Train 0.3769  Val 0.3462  LR 5.00e-04
# Epoch  45  Train 0.3770  Val 0.3462  LR 5.00e-04
# Epoch  46  Train 0.3770  Val 0.3461  LR 5.00e-04
#   ✓ Saved best model
# Epoch  47  Train 0.3769  Val 0.3463  LR 5.00e-04
# Epoch  48  Train 0.3771  Val 0.3462  LR 5.00e-04
# Epoch  49  Train 0.3770  Val 0.3462  LR 5.00e-04
# Epoch  50  Train 0.3770  Val 0.3461  LR 5.00e-04
# Epoch  51  Train 0.3770  Val 0.3464  LR 5.00e-04
# Epoch  52  Train 0.3770  Val 0.3462  LR 5.00e-04
# Epoch  53  Train 0.3769  Val 0.3460  LR 5.00e-04
#   ✓ Saved best model
# Epoch  54  Train 0.3769  Val 0.3462  LR 5.00e-04
# Epoch  55  Train 0.3770  Val 0.3461  LR 5.00e-04
# Epoch  56  Train 0.3770  Val 0.3464  LR 5.00e-04
# Epoch  57  Train 0.3769  Val 0.3463  LR 5.00e-04
# Epoch  58  Train 0.3770  Val 0.3460  LR 5.00e-04
# Epoch  59  Train 0.3769  Val 0.3460  LR 5.00e-04
# Epoch  60  Train 0.3770  Val 0.3461  LR 5.00e-04
# Epoch  61  Train 0.3768  Val 0.3460  LR 5.00e-04
# Epoch  62  Train 0.3769  Val 0.3460  LR 5.00e-04  → LR dropped to 2.50e-04
# Epoch  63  Train 0.3765  Val 0.3459  LR 2.50e-04
#   ✓ Saved best model
# Epoch  64  Train 0.3765  Val 0.3458  LR 2.50e-04
#   ✓ Saved best model
# Epoch  65  Train 0.3765  Val 0.3459  LR 2.50e-04
# Epoch  66  Train 0.3766  Val 0.3458  LR 2.50e-04
#   ✓ Saved best model
# Epoch  67  Train 0.3766  Val 0.3459  LR 2.50e-04
# Epoch  68  Train 0.3767  Val 0.3459  LR 2.50e-04
# Epoch  69  Train 0.3766  Val 0.3458  LR 2.50e-04
#   ✓ Saved best model
# Epoch  70  Train 0.3765  Val 0.3460  LR 2.50e-04
# Epoch  71  Train 0.3765  Val 0.3459  LR 2.50e-04
# Epoch  72  Train 0.3766  Val 0.3458  LR 2.50e-04
# Epoch  73  Train 0.3766  Val 0.3458  LR 2.50e-04
#   ✓ Saved best model
# Epoch  74  Train 0.3764  Val 0.3457  LR 2.50e-04
#   ✓ Saved best model
# Epoch  75  Train 0.3765  Val 0.3459  LR 2.50e-04
# Epoch  76  Train 0.3765  Val 0.3459  LR 2.50e-04

# %%
# results = {}

# # # -------- 0% --------
# # print("\n========== 0% Missing ==========")

# # results[0] = train_single_dataset(0, "pemabay_iconv_0")

# # mae, rmse, r2, mape = results[0]
# # print("\nFINAL RESULT 0%")
# # print(f"MAE  : {mae:.4f}")
# # print(f"RMSE : {rmse:.4f}")
# # print(f"R2   : {r2:.4f}")
# # print(f"MAPE : {mape:.2f}%")

# # clear_memory()


# # -------- 10% --------
# print("\n========== 10% Missing ==========")

# results[10] = train_single_dataset(10, "pemabay_iconv_10")

# mae, rmse, r2, mape = results[10]
# print("\nFINAL RESULT 10%")
# print(f"MAE  : {mae:.4f}")
# print(f"RMSE : {rmse:.4f}")
# print(f"R2   : {r2:.4f}")
# print(f"MAPE : {mape:.2f}%")

# clear_memory()


# # # -------- 20% --------
# # print("\n========== 20% Missing ==========")

# # results[20] = train_single_dataset(20, "pemabay_iconv_20")

# # mae, rmse, r2, mape = results[20]
# # print("\nFINAL RESULT 20%")
# # print(f"MAE  : {mae:.4f}")
# # print(f"RMSE : {rmse:.4f}")
# # print(f"R2   : {r2:.4f}")
# # print(f"MAPE : {mape:.2f}%")

# # clear_memory()


# # -------- 40% --------
# print("\n========== 40% Missing ==========")

# results[40] = train_single_dataset(40, "pemabay_iconv_40")

# mae, rmse, r2, mape = results[40]
# print("\nFINAL RESULT 40%")
# print(f"MAE  : {mae:.4f}")
# print(f"RMSE : {rmse:.4f}")
# print(f"R2   : {r2:.4f}")
# print(f"MAPE : {mape:.2f}%")

# clear_memory()


# # # -------- 80% --------
# # print("\n========== 80% Missing ==========")

# # results[80] = train_single_dataset(80, "pemabay_iconv_80")

# # mae, rmse, r2, mape = results[80]
# # print("\nFINAL RESULT 80%")
# # print(f"MAE  : {mae:.4f}")
# # print(f"RMSE : {rmse:.4f}")
# # print(f"R2   : {r2:.4f}")
# # print(f"MAPE : {mape:.2f}%")

# # clear_memory()


# # # -------- SUMMARY --------
# # print("\n==============================")
# # print("FINAL SUMMARY (PEMABAY IConvLSTM)")
# # print("==============================")

# # for k in [0, 10, 20, 40, 80]:
# #     mae, rmse, r2, mape = results[k]
# #     print(f"{k}% -> MAE: {mae:.4f}, RMSE: {rmse:.4f}, R2: {r2:.4f}, MAPE: {mape:.2f}%")
